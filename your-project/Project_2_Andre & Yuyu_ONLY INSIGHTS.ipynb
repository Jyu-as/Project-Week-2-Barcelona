# %%
import numpy as pd
import pandas as pd

# %%
Final_Dataset_Insights = pd.read_csv('DATASET_2017_NATALITY_PER_NEIGHBORHOOD')

# %%
Final_Dataset_Insights
# Out:
#     Unnamed: 0  Year  District Code District Name  Neighborhood Code  \
# 0            0  2017              1  Ciutat Vella                  1
# 1            1  2017              1  Ciutat Vella                  2
# 2            2  2017              1  Ciutat Vella                  3
# 3            3  2017              1  Ciutat Vella                  4
# 4            4  2017              2      Eixample                  5
# ..         ...   ...            ...           ...                ...
# 68          68  2017             10    Sant Martí                 69
# 69          69  2017             10    Sant Martí                 70
# 70          70  2017             10    Sant Martí                 71
# 71          71  2017             10    Sant Martí                 72
# 72          72  2017             10    Sant Martí                 73
#
#                                Neighborhood Name  Total Boys Birth  \
# 0                                       el Raval               283
# ...
